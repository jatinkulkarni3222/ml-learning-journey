# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('/content/subplot.png')

# %%
plt.imshow(img)
plt.show()

# %%
import cv2

# %%
imgcv2=cv2.imread('/content/subplot.png')
plt.imshow(imgcv2)
plt.show()

# %%
imgcv2 = cv2.cvtColor(imgcv2, cv2.COLOR_BGR2RGB)


plt.imshow(imgcv2)
plt.show()

# %%
plt.imshow(img, aspect = 0.5)
plt.show()

# %%
img1 = mpimg.imread('/content/subplot.png')
img2 = mpimg.imread('/content/subplot.png')
img3 = mpimg.imread('/content/subplot.png')
img4 = mpimg.imread('/content/subplot.png')

# %%
plt.figure()
plt.subplot(2,2,1)
plt.imshow(img1,cmap='plasma')
plt.colorbar()
plt.subplot(2,2,2)
plt.imshow(img2,cmap='hot')
plt.colorbar()
plt.subplot(2,2,3)
plt.imshow(img3,cmap='cool')
plt.colorbar()
plt.subplot(2,2,4)
plt.imshow(img4,cmap='viridis')
plt.colorbar()
plt.show()
