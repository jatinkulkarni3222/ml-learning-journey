# %%
# !pip install mysql-connector-python

# %%
import mysql.connector
import pandas as pd

# %%
conn = mysql.connector.connect(
    host="localhost",
    port=3307,
    user="root",
    password="",
    database="world"
)

# %%
df=pd.read_sql_query("select * from city where CountryCode like'IND'",conn,index_col='ID')
df
# Out:
# /var/folders/m9/flkvrdc10lncr1p8j9cv4rhc0000gn/T/ipykernel_31047/4199321059.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql_query("select * from city where CountryCode like'IND'",conn,index_col='ID')
#                     Name CountryCode        District  Population
# ID
# 1024     Mumbai (Bombay)         IND     Maharashtra    10500000
# 1025               Delhi         IND           Delhi     7206704
# 1026  Calcutta [Kolkata]         IND    West Bengali     4399819
# 1027    Chennai (Madras)         IND      Tamil Nadu     3841396
# 1028           Hyderabad         IND  Andhra Pradesh     2964638
# ...                  ...         ...             ...         ...
# 1360        Ambala Sadar         IND         Haryana       90712
# 1361          Baidyabati         IND    West Bengali       90601
# ...
